# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.cluster import AgglomerativeClustering
import scipy.cluster.hierarchy as sch

# %%
#load dataset
iris = load_iris()
x= iris.data[:,:2]

# %%
#reduce data
x_small = x[:20]

# %%
#dendogram
plt.figure(figsize=(10,7))
sch.dendrogram(
    sch.linkage(x_small,method='ward'),
labels=[f"P{i}" for i in range(len(x_small))]
)

plt.title("Dendogram")
plt.ylabel("Data points")
plt.xlabel("Euclidean distance")
plt.show()

# %%
#Agglomerative clustering
agg=AgglomerativeClustering(n_clusters=2)
y_agg=agg.fit_predict(x_small)
plt.scatter(x_small[:,0],x_small[:,1],c=y_agg,cmap='rainbow')
plt.title("Agglomerative Clustering (reduced Data)")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.show()

# %% [markdown]
# MALL CUSTOMERS DATASET

# %%
#LOAD DATASET
df=pd.read_csv('Mall_Customers.csv')
df.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
x_s = x[:30]

# %%
#dendogram
plt.figure(figsize=(10,7))
sch.dendrogram(
    sch.linkage(x_s,method='ward'),
labels=[f"P{i}" for i in range(len(x_s))]
)

plt.title("Dendogram")
plt.ylabel("Data points")
plt.xlabel("Euclidean distance")
plt.show()

# %%
#Agglomerative clustering
agg=AgglomerativeClustering(n_clusters=2)
y_agg=agg.fit_predict(x_s)
plt.scatter(x_s[:,0],x_s[:,1],c=y_agg,cmap='rainbow')
plt.title("Agglomerative Clustering (reduced Data)")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.show()
